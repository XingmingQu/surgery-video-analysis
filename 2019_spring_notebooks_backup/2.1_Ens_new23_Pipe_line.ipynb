# %%
import pandas as pd
import numpy as np
import cv2
import os
from os.path import join as pjoin
from matplotlib import pyplot as plt
import random
import warnings
import keras
from keras.callbacks import EarlyStopping
from keras.regularizers import l2 
from keras.models import Sequential
from keras.layers import Reshape
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D,Conv1D,GlobalMaxPooling1D,MaxPooling1D
from keras.layers import Conv1D, GlobalAveragePooling1D, MaxPooling1D,AveragePooling1D
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping
from keras.regularizers import l2
from keras.layers import average 
from keras.models import Input, Model
from sklearn import metrics as mt
from matplotlib import pyplot as plt
from skimage.io import imshow
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
warnings.filterwarnings('ignore')
# Out:
# Using TensorFlow backend.

# %%
# Video_label=pd.read_excel('new23label.xlsx')
# group=Video_label.groupby('label')
# M=group.mean()
# M.to_csv('new23label.csv')
# random.uniform(-0.3, 0.3)

# %%
# first we can see what does the feature look like
def get_raw_feature():
    video_data_dir='new23feature'
    X=[]
    Y=[]
    for video in os.listdir(video_data_dir):
        each_video= pjoin(video_data_dir,video)
        ## 'C:\\videofeature\\' using
#         l=each_video.split('t_')[1]

        # 'C:\\new_video_feature\\' using
        l=each_video.split('e_')[1]
        l=l.split('.')[0]
        LABEL=int(l)
        X.append(np.load(each_video))
        Y.append(LABEL)
#     Video_label=pd.read_csv('label.csv')
# #     Video_label=np.array(Video_label)[:,:-1]
    return X,Y

# %% [markdown]
# ## 1 Read features from 19 npy files

# %%
X,Y=get_raw_feature()
Video_label=pd.read_csv('newall_label.csv')
# Video_label=np.array(Video_label)[:,:-1]
print('there are ',len(X),'videos')
print('feature of video [0]',X[0].shape)
print('video [0] is from video' ,Y[0])
print(Y)
# Out:
# there are  23 videos
# feature of video [0] (153, 14)
# video [0] is from video 11
# [11, 113, 130, 143, 152, 164, 16, 171, 192, 176, 207, 194, 236, 237, 240, 253, 258, 257, 49, 59, 74, 78, 91]

# %%
Video_label
# Out:
#     GEARS - Depth Perception  GEARS - Bimanual Dexterity  GEARS - Efficiency  \
# 0                   2.000000                    1.666667            2.000000
# 1                   1.333333                    1.000000            1.000000
# 2                   3.000000                    3.000000            2.000000
# 3                   2.333333                    1.666667            1.666667
# 4                   1.000000                    1.000000            1.000000
# 5                   2.500000                    3.000000            2.000000
# 6                   4.000000                    4.000000            4.000000
# 7                   2.500000                    3.000000            2.500000
# 8                   3.000000                    3.000000            2.500000
# 9                   3.000000                    2.500000            2.500000
# 10                  4.000000                    5.000000            4.000000
# 11                  4.000000                    5.000000            5.000000
# 12                  5.000000                    5.000000            5.000000
# 13                  2.000000                    1.000000            1.000000
# 14                  4.000000                    4.000000            3.000000
# 15                  4.000000                    4.000000            4.000000
# 16                  4.000000                    4.000000            3.000000
# 17                  1.000000                    1.000000            1.000000
# 18                  2.000000                    1.000000            2.000000
# 19                  2.000000                    1.000000            1.000000
# 20                  2.000000                    1.000000            1.000000
# 21                  5.000000                    5.000000            5.000000
# 22                  3.000000                    4.000000            3.000000
# 23                  1.330000                    1.670000            1.000000
# 24                  0.000000                    0.000000            0.000000
# 25                  1.670000                    1.000000            1.000000
# 26                  4.330000                    4.330000            4.330000
# 27                  2.330000                    1.670000            2.000000
# 28                  3.330000                    3.330000            2.670000
# 29                  4.670000                    4.000000            4.000000
# 30                  2.000000                    2.000000            1.330000
# 31                  1.330000                    1.670000            1.330000
# 32                  2.670000                    2.670000            2.670000
# 33                  1.330000                    1.670000            1.000000
# 34                  2.670000                    2.670000            1.670000
# 35                  3.670000                    3.330000            3.000000
# 36                  1.670000                    2.000000            1.000000
# 37                  5.000000                    5.000000            5.000000
# 38                  1.330000                    1.000000            1.330000
# 39                  1.670000                    1.670000            1.000000
# 40                  4.330000                    4.330000            4.000000
# 41                  4.000000                    3.000000            3.000000
# 42                  4.000000                    3.500000            4.500000
#
#     GEARS - Force Sensitivity  GEARS - Autonomy  GEARS - Robotic Control  \
# 0                    1.333333          2.666667                 2.333333
# 1                    1.000000          1.000000                 1.333333
# 2                    2.333333          2.666667                 2.666667
# 3                    2.000000          1.666667                 1.666667
# 4                    1.000000          1.000000                 1.000000
# 5                    2.000000          2.500000                 2.000000
# 6                    4.500000          4.500000                 5.000000
# 7                    2.500000          3.000000                 2.500000
# 8                    2.500000          3.000000                 3.000000
# 9                    2.000000          2.500000                 2.500000
# 10                   4.000000          5.000000                 4.000000
# 11                   5.000000          4.000000                 5.000000
# 12                   4.000000          5.000000                 5.000000
# 13                   1.000000          1.000000                 1.000000
# 14                   4.000000          4.000000                 4.000000
# 15                   3.000000          4.000000                 3.000000
# 16                   3.000000          4.000000                 3.000000
# 17                   1.000000          1.000000                 1.000000
# 18                   2.000000          2.000000                 1.000000
# 19                   1.000000          1.000000                 1.000000
# 20                   1.000000          1.000000                 1.000000
# 21                   4.000000          5.000000                 5.000000
# 22                   4.000000          4.000000                 3.000000
# 23                   1.670000          1.330000                 1.000000
# 24                   0.000000          0.000000                 0.000000
# 25                   1.670000          1.330000                 1.330000
# 26                   4.330000          5.000000                 4.670000
# 27                   2.000000          3.000000                 2.330000
# 28                   3.330000          4.000000                 3.670000
# 29                   4.670000          5.000000                 4.670000
# 30                   1.000000          1.330000                 2.330000
# 31                   1.330000          1.000000                 1.670000
# 32                   2.330000          3.330000                 3.000000
# 33                   1.330000          2.000000                 1.330000
# 34                   2.670000          2.670000                 2.330000
# 35                   3.000000          3.670000                 3.330000
# 36                   1.670000          1.670000                 2.000000
# 37                   4.670000          5.000000                 4.670000
# 38                   1.000000          1.000000                 1.670000
# 39                   2.000000          2.330000                 1.670000
# 40                   4.000000          4.330000                 4.330000
# 41                   4.500000          4.000000                 4.000000
# 42                   4.000000          4.500000                 4.500000
#
#     label
# 0      11
# 1      16
# 2      49
# 3      59
# 4      74
# 5      78
# 6      91
# 7     113
# 8     130
# 9     143
# 10    152
# 11    164
# 12    171
# 13    176
# 14    192
# 15    194
# 16    207
# 17    236
# 18    237
# 19    240
# 20    253
# 21    257
# 22    258
# 23      1
# 24      2
# 25      3
# 26      4
# 27      5
# 28      6
# 29      7
# 30      8
# 31      9
# 32     10
# 33   1111
# 34     12
# 35     13
# 36     14
# 37     15
# 38   1611
# 39     17
# 40     18
# 41     19
# 42     20

# %% [markdown]
# Video_label contains detail labels and we can use Y to index them later.

# %%
def getlabel(number):
    L=Video_label[Video_label['label']==number]
    L=np.array(L)[:,:-1]
    L= np.squeeze(L)
    return L
# def getlabel_addnoise(number):
#     L=Video_label[Video_label['label']==number]
#     L=np.array(L)[:,:-1]
#     L= np.squeeze(L)
#     noise=np.array([random.uniform(-0.4, 0.4) for _ in range(len(L))])
# #     print(noise)
#     return L+noise

# %%
# noise=getlabel_addnoise(16)
# print(noise)

# %% [markdown]
# Here we create two functions to sample video clips from each video and get their time differences.

# %%
def get_diff_and_hstack_to_orginal_data(X,time_lag=2,move_threshold=200):
    original=X[:-time_lag]
    modified=X[time_lag:]
    result=modified-original
    ## threshold
    # consider there was no top in the first image and it showed up in the next image
    # the difference would be huge, which was not ideal.
    # so we need to filter these extrem value 
    result[np.abs(result)>move_threshold]=0
    
    return np.hstack((X[time_lag:],result))

##from each video sample video clips with size=window_L. you can specify stride 
def make_video_clips(matrix,window_L,stride):
    alldata=[]

    total_frame=matrix.shape[0]
    index=[n for n in range(1,total_frame,stride)]
    for start_index in index:
        if start_index+window_L> total_frame:
            break
#         print(start_index)
        each_clip_data=matrix[start_index:start_index+window_L]
#         each_clip_data=np.transpose(each_clip_data)
#         print(each_clip_data.shape)
        alldata.append(each_clip_data)
    return np.array(alldata)

# %% [markdown]
# ## 2 pre-processing the feature
# make new 28-d feature and  sample video clips

# %%
####################################### set video clips parameters
############################################### make new 28-d feature
video_clips_length=30
time_lag=2
move_threshold=150
stride=video_clips_length

####################################### set video clips parameters
############################################### make new 28-d feature
all_data=[]
for each_video,label in zip(X,Y):

    re=get_diff_and_hstack_to_orginal_data(each_video,time_lag,move_threshold)
#     re=each_video
    video_clip=make_video_clips(re,video_clips_length,stride)
    print(video_clip.shape)
    all_data.append((video_clip))
# Out:
# (5, 30, 28)
# (4, 30, 28)
# (10, 30, 28)
# (20, 30, 28)
# (10, 30, 28)
# (40, 30, 28)
# (100, 30, 28)
# (19, 30, 28)
# (5, 30, 28)
# (100, 30, 28)
# (10, 30, 28)
# (100, 30, 28)
# (10, 30, 28)
# (5, 30, 28)
# (20, 30, 28)
# (40, 30, 28)
# (9, 30, 28)
# (99, 30, 28)
# (20, 30, 28)
# (40, 30, 28)
# (20, 30, 28)
# (10, 30, 28)
# (10, 30, 28)

# %%
c=all_data[0]

# %%
c[0][2]
# Out:
# array([ 49, 183,   0,   0, 140, 160, 327,  72, 202, 162, 279,  77, 266,
#        128, -35,   0,   0,   0, -29,  -1,   0,  72, -41,  -8,   1,   1,
#         -2,   1], dtype=int32)

# %% [markdown]
# So there are 19 videos and you can see how many video clips they have.
#
# And next we will use leave one method to train the model.

# %% [markdown]
# ## 3 prepare leave one data and give every video clips their label

# %%
# this function is used to stack 18 videos into a big matrix
# the dimenstion will be 
# (n1+n2..+n18,28,30)
# and the label will be (n1+n2..+n18,6)

def stack_video_clips_get_label(data,label):
    final_data=data[0]

    final_label=[getlabel(label[0]) for _ in range(final_data.shape[0])]
#     print(len(final_label))
#     print(final_data.shape)
    for i in range(1,len(data)):
        final_data=np.vstack((final_data,data[i]))
        for j in range(data[i].shape[0]):
            final_label.append(getlabel(label[i]))
    return final_data,np.array(final_label)

########## leave one and stack all video clips
def hold_out(X,Y,hold_number):
        new_label=Y.copy()
        new_data=X.copy()
        # find video n 's index
        index=new_label.index(hold_number)
        # get the video n and it's label
        X_test=new_data[index]
        test_label=getlabel(hold_number)
        y_test=np.array([test_label for _ in range(X_test.shape[0])])
#         # so we can del them 
        del new_label[index]
        del new_data[index]
#         print(new_label)
        final_data_X,final_data_Y=stack_video_clips_get_label(new_data,new_label)

        return final_data_X,X_test,final_data_Y,y_test

# %%
# hold_out_number=130
# X_train, X_test, y_train, y_test=hold_out(all_data,Y,hold_out_number)
# print(X_train.shape)
# print(X_test.shape)
# print(y_train.shape)
# print(y_test.shape)
# new_label=Y.copy()
# new_data=X.copy()
# # find video n 's index
# index=new_label.index(hold_number)
# get the video n and it's label
# X_test=new_data[index]
# test_label=getlabel(11)
# y_test=np.array([test_label for _ in range(X_test.shape[0])])

# %%
# customized data generator
def generator_noise(data, label, batch_size=64):
    while 1:
        rows = np.random.randint(0, data.shape[0], size=batch_size)

        samples = data[rows]
        y=label[rows]
        noise=np.random.uniform(low=-0.5, high=0.5, size=(y.shape[0],y.shape[1]))
        y=y+noise
        yield samples,y
        
def generator(data, label, batch_size=64):
    while 1:
        rows = np.random.randint(0, data.shape[0], size=batch_size)

        samples = data[rows]
        y=label[rows]
#         noise=np.random.uniform(low=-0.5, high=0.5, size=(y.shape[0],y.shape[1]))
#         y=y+noise
        yield samples,y

# %%
# X_train, X_test, y_train, y_test=hold_out(all_data,Y,5)

# train_gen=generator(X_train, y_train, 10)

# %%
# print(X_train.shape)
# print(X_test.shape)
# print(y_train.shape)
# print(y_test.shape)

# %%
# a,b=next(train_gen)
# b.shape

# %%
# for each col, calculate the weighted average
def get_weighted_average(df):
    length=len(df)
    top=int(1/6*length)
    bottom=length-top
    df=np.array(df)
    df=np.sort(df)
    weghted_sum=np.sum(df[:top]*(1/6))+np.sum(df[top+1:bottom]*(2/3))+np.sum(df[bottom+1:]*(1/6))
    weghted_sum=weghted_sum/length
    return weghted_sum

# make the data frame
# Plot_data is the pridect result, which will have 6 scores
def get_video_score(Plot_data,GT):
    weight_ave_re=[]
    mean_re=[]
    median_re=[]
    pooled_re=[]
    
    for i in Plot_data.columns:
        weight_ave=get_weighted_average(Plot_data[i])
        weight_ave_re.append(weight_ave)
        
        mean_value=np.mean(Plot_data[i])   
        mean_re.append(mean_value)
        
        median_value = np.median(Plot_data[i])
        median_re.append(median_value)
        
        # pooling is also a weighted average 
        pooling = (weight_ave*0.2 + mean_value*0.2 + median_value*0.6)
        
        pooled_re.append(pooling)
        
    video_result=pd.DataFrame([weight_ave_re,mean_re,median_re,pooled_re,GT])
    video_result.columns = ['DP','BD','E','FS','A','RC']
    video_result.index = ['Weighted_average', 'Mean', 'Median','Cool_pooling','Ground_truth']
    return video_result

# %% [markdown]
# ## 3 perform leave one cross validation

# %%
# from keras.models import Sequential
# from keras.layers import LSTM, Dense

# def make_lstm(timesteps = video_clips_length,drop=0.2):
#     data_dim = 28
#     dropout=drop
#     recurrent_dropout=drop

#     input_holder = Input(shape=(timesteps, data_dim))


# #     x = LSTM(64,dropout=drop, recurrent_dropout=drop,return_sequences=True)(input_holder)
# #     x = LSTM(32,dropout=drop, recurrent_dropout=drop)(x)
#     x = LSTM(50,dropout=drop, recurrent_dropout=drop)(input_holder)
#     x = Dense(32, activation='relu')(x)
#     x = Dense(6, activation='sigmoid')(x)
#     model=Model(inputs=input_holder,outputs=x)
    
# #     # expected input data shape: (batch_size, timesteps, data_dim)
# # #     model = Sequential()
# # #     model.add(Input())
# # #     model.add(LSTM(64,dropout=drop, recurrent_dropout=drop, return_sequences=True,
# # #                    ))  # returns a sequence of vectors of dimension 32
# # #     # model.add(LSTM(32, return_sequences=True))  # returns a sequence of vectors of dimension 32
# # #     model.add(LSTM(32,dropout=drop, recurrent_dropout=drop))  # return a single vector of dimension 32
# # #     model.add(Dense(6, activation='sigmoid'))

#     model.compile(loss='categorical_crossentropy',
#                   optimizer='adam',
#                   )
    
    
# #     model.summary()
#     return model


# ls=make_lstm()

# %%
from keras.layers import average, concatenate
from keras.models import Input, Model
def make_model_ens(l2_lambda,clip_lenth,dimension):


    input_holder = Input(shape=(clip_lenth, dimension))
    
    branches=[]

    # start with a conv layer
    ### first branch
    x = Conv1D(filters=8, 
                     kernel_size=15, 
                     padding='same',
                     activation='relu', 
                     input_shape=(clip_lenth, dimension),
                     kernel_regularizer=l2(l2_lambda))(input_holder)

    x = Conv1D(filters=8, 
                     kernel_size=10, 
                     padding='same',
                     activation='relu', 
                     input_shape=(clip_lenth, dimension),
                     kernel_regularizer=l2(l2_lambda))(x)
    x= MaxPooling1D(2,padding='same')(x)
    
    x = Conv1D(filters=16, 
                     kernel_size=5, 
                     padding='same',
                     activation='relu', 
                     input_shape=(clip_lenth, dimension),
                     kernel_regularizer=l2(l2_lambda))(x)

    x = Conv1D(filters=16, 
                     kernel_size=5, 
                     padding='same',
                     activation='relu', 
                     input_shape=(clip_lenth, dimension),
                     kernel_regularizer=l2(l2_lambda))(x)
    
    branches.append(x)

    ### second branch
    x = Conv1D(filters=8, 
                     kernel_size=10, 
                     padding='same',
                     activation='relu', 
                     input_shape=(clip_lenth, dimension),
                     kernel_regularizer=l2(l2_lambda))(input_holder)

    x = Conv1D(filters=8, 
                     kernel_size=5, 
                     padding='same',
                     activation='relu', 
                     input_shape=(clip_lenth, dimension),
                     kernel_regularizer=l2(l2_lambda))(x)
    x= MaxPooling1D(2,padding='same')(x)
    
    x = Conv1D(filters=16, 
                     kernel_size=3, 
                     padding='same',
                     activation='relu', 
                     input_shape=(clip_lenth, dimension),
                     kernel_regularizer=l2(l2_lambda))(x)

    x = Conv1D(filters=16, 
                     kernel_size=3, 
                     padding='same',
                     activation='relu', 
                     input_shape=(clip_lenth, dimension),
                     kernel_regularizer=l2(l2_lambda))(x)
    
    branches.append(x)
    
    ### third branch
#     x = Conv1D(filters=4, 
#                      kernel_size=5, 
#                      padding='same',
#                      activation='relu', 
#                      input_shape=(clip_lenth, dimension),
#                      kernel_regularizer=l2(l2_lambda))(input_holder)

#     x = Conv1D(filters=4, 
#                      kernel_size=3, 
#                      padding='same',
#                      activation='relu', 
#                      input_shape=(clip_lenth, dimension),
#                      kernel_regularizer=l2(l2_lambda))(x)
#     x= MaxPooling1D(2,padding='same')(x)
    
#     x = Conv1D(filters=4, 
#                      kernel_size=3, 
#                      padding='same',
#                      activation='relu', 
#                      input_shape=(clip_lenth, dimension),
#                      kernel_regularizer=l2(l2_lambda))(x)

#     x = Conv1D(filters=4, 
#                      kernel_size=3, 
#                      padding='same',
#                      activation='relu', 
#                      input_shape=(clip_lenth, dimension),
#                      kernel_regularizer=l2(l2_lambda))(x)
    
#     branches.append(x)

#     # five
#     x = Conv1D(filters=4, 
#                      kernel_size=15, 
#                      padding='same',
#                      activation='relu', 
#                      input_shape=(clip_lenth, dimension),
#                      kernel_regularizer=l2(l2_lambda))(input_holder)
    
#     x= MaxPooling1D(2,padding='same')(x)
    
#     x = Conv1D(filters=4, 
#                      kernel_size=5, 
#                      padding='same',
#                      activation='relu', 
#                      input_shape=(clip_lenth, dimension),
#                      kernel_regularizer=l2(l2_lambda))(x)
#     branches.append(x)
#     input_conv = MaxPooling2D(pool_size=(2, 2), data_format="channels_last")(x)



        # add one layer on flattened output
    x = concatenate(branches)
    
    x = Flatten()(x)
    
#     x = Dense(128, 
#               activation='relu',
#               kernel_initializer='he_uniform',
#               kernel_regularizer=l2(l2_lambda)
#             )(x)

#     x = Dropout(0.40)(x) # add some dropout for regularization after conv layers
    x = Dense(64, 
              activation='relu',
              kernel_initializer='he_uniform',
              kernel_regularizer=l2(l2_lambda)
            )(x)

    x = Dropout(0.5)(x) # add some dropout for regularization after conv layers
    
    x = Dense(6, 
              activation='sigmoid', 
              kernel_initializer='glorot_uniform',
              kernel_regularizer=l2(l2_lambda)
             )(x)

    # here is the secret sauce for setting the network using the 
    #   Functional API:
    cnn_ens = Model(inputs=input_holder,outputs=x)
    cnn_ens.compile(loss='mean_squared_error', # 'categorical_crossentropy' 'mean_squared_error' 'mean_absolute_percentage_error'
              optimizer='adam') # 'adadelta' 'rmsprop'
                  
    cnn_ens.summary()    
    return cnn_ens

make_model_ens(0.001,60,28)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 60, 28)       0
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 60, 8)        3368        input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 60, 8)        2248        input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 60, 8)        648         conv1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 60, 8)        328         conv1d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 30, 8)        0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 30, 8)        0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 30, 16)       656         max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 30, 16)       400         max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 30, 16)       1296        conv1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 30, 16)       784         conv1d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 30, 32)       0           conv1d_4[0][0]
#                                                                  conv1d_8[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 960)          0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           61504       flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 6)            390         dropout_1[0][0]
# ==================================================================================================
# Total params: 71,622
# Trainable params: 71,622
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# the model we will use
def make_model_1d(l2_lambda,clip_lenth,dimension):



    
    model = Sequential()
    model.add(Conv1D(filters=8, 
                     kernel_size=15, 
                     padding='same',
                     activation='relu', 
                     input_shape=(clip_lenth, dimension),
                     kernel_regularizer=l2(l2_lambda)))
    
    model.add(Conv1D(filters=8, 
                     kernel_size=10, 
                     padding='same',
                     activation='relu',
                     kernel_regularizer=l2(l2_lambda)))

#     model.add(Conv1D(filters=8, 
#                      kernel_size=5, 
#                      padding='same',
#                      activation='relu',
#                      kernel_regularizer=l2(l2_lambda)))
    
    model.add(MaxPooling1D(2,
                          padding='same'))
    
    model.add(Conv1D(filters=16, 
                     kernel_size=5, 
                     padding='same',
                     activation='relu',
                     kernel_regularizer=l2(l2_lambda)))
    model.add(Conv1D(filters=16, 
                     kernel_size=5, 
                     padding='same',
                     activation='relu',
                     kernel_regularizer=l2(l2_lambda)))
    
#     model.add(Conv1D(filters=16, 
#                      kernel_size=5, 
#                      padding='same',
#                      activation='relu',
#                      kernel_regularizer=l2(l2_lambda)))
    
#     model.add(GlobalMaxPooling1D())
    model.add(Flatten())
#     model.add(Dense(128, activation='relu'))
#     model.add(Dropout(0.5))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(6, activation='sigmoid'))
    
    model.compile(loss='mean_squared_error', # 'categorical_crossentropy' 'mean_squared_error' 'mean_absolute_percentage_error'
              optimizer='adam', # 'adadelta' 'rmsprop'
              )
# #     model.summary()
    return model

# %%
def test_hold_out(model_name,hold_out_number,E,show_result=False):
    # using leave one cv to get train/test data
    X_train, X_test, y_train, y_test=hold_out(all_data,Y,hold_out_number)
    
    # scale all the value to 0-1
    X_train=X_train/640-0.5
    X_test=X_test/640-0.5
    y_train=y_train/5
    y_test=y_test/5
    # print(X_train.shape,y_train.shape)
    # print(X_test.shape,y_test.shape)

    sample_of_trainningdata=X_train.shape[0]
    sample_of_testdata=X_test.shape[0]


    batch_size=64
    l2=0.005


    train_gen=generator_noise(X_train, y_train, batch_size)
    val_gen=generator(X_test, y_test, batch_size)
    
    #prepare for inout shape
    clip_lenth=X_train.shape[1]
    dimension=X_train.shape[2]
    
    #make cnn 1d
    if model_name=='ENS':
        model=make_model_ens(l2,clip_lenth,dimension)
        
    if model_name=='LSTM':
        model=make_lstm()
    if model_name=='CNN':    
        model=make_model_1d(l2,clip_lenth,dimension)
        
    model_h=model.fit_generator(train_gen,
                        steps_per_epoch=sample_of_trainningdata//batch_size,
                        epochs=E,
                        validation_data=val_gen,
                       validation_steps=sample_of_testdata//batch_size +1 ,
                        verbose=0 )
#     model_h=model.fit(X_train, y_train, epochs=40, batch_size=64, validation_data=(X_test, y_test),
#        verbose=0  )
    
    
    if show_result:
        ax=plt.figure(figsize=(10,6))
        ax = plt.subplot(221)
        ax.plot(model_h.history['loss'])
        plt.ylabel('Training Loss')
        plt.xlabel('epochs')

        ax = plt.subplot(222)
        ax.plot(model_h.history['val_loss'])
        plt.ylabel('valadation Loss')
        plt.xlabel('epochs')

        print('loss',model_h.history['val_loss'][-1])

        GT=list(getlabel(hold_out_number))

        #get pridect result
        predict=model.predict(X_test)
        print(X_test.shape)
        re=predict*5
#         print(re)
        Plot_data=pd.DataFrame(re,columns=['DP','BD','E','FS','A','RC'])
        video_result=get_video_score(Plot_data,GT)
#         print(video_result)

        y=[x for x in range(1,7)]
        ax = plt.subplot(223)
        gt=video_result.iloc[4]
        re=video_result.iloc[3]
        ax.plot(y, re, label='predict')
        ax.plot(y, gt, label='ground truth')
        plt.ylim(0,5.5)
        ax.legend()
        plt.show()
    return model_h.history['val_loss'][-1]

# %%
# print(Y)
# model_name='CNN'
# print("you can try the video number above")
# test_hold_out(model_name,152,show_result=True)

# %%
####un-comment the code blow to test all the video
total_loss=0
show_result=True
model_name='ENS'
for i in Y:
    print('video',i)
    loss=test_hold_out(model_name,i,45,show_result)
    total_loss=total_loss+loss
print('total_loss= ',total_loss)
# Out:
# video 11
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 30, 28)       0
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 30, 8)        3368        input_2[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 30, 8)        2248        input_2[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 30, 8)        648         conv1d_9[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 30, 8)        328         conv1d_13[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 15, 8)        0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 15, 8)        0           conv1d_14[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 15, 16)       656         max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 15, 16)       400         max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 15, 16)       1296        conv1d_11[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 15, 16)       784         conv1d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 15, 32)       0           conv1d_12[0][0]
#                                                                  conv1d_16[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 480)          0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64)           30784       flatten_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64)           0           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 6)            390         dropout_2[0][0]
# ==================================================================================================
# Total params: 40,902
# Trainable params: 40,902
# Non-trainable params: 0
# __________________________________________________________________________________________________
# loss 0.02253188006579876
# (5, 30, 28)
# video 113
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 30, 28)       0
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 30, 8)        3368        input_3[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 30, 8)        2248        input_3[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 30, 8)        648         conv1d_17[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 30, 8)        328         conv1d_21[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 15, 8)        0           conv1d_18[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_6 (MaxPooling1D)  (None, 15, 8)        0           conv1d_22[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 15, 16)       656         max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 15, 16)       400         max_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 15, 16)       1296        conv1d_19[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 15, 16)       784         conv1d_23[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 15, 32)       0           conv1d_20[0][0]
#                                                                  conv1d_24[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 480)          0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 64)           30784       flatten_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64)           0           dense_5[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 6)            390         dropout_3[0][0]
# ==================================================================================================
# Total params: 40,902
# Trainable params: 40,902
# Non-trainable params: 0
# __________________________________________________________________________________________________
# loss 0.0030410783365368843
# (4, 30, 28)
# video 130
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 30, 28)       0
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 30, 8)        3368        input_4[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 30, 8)        2248        input_4[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 30, 8)        648         conv1d_25[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 30, 8)        328         conv1d_29[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_7 (MaxPooling1D)  (None, 15, 8)        0           conv1d_26[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_8 (MaxPooling1D)  (None, 15, 8)        0           conv1d_30[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 15, 16)       656         max_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 15, 16)       400         max_pooling1d_8[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 15, 16)       1296        conv1d_27[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 15, 16)       784         conv1d_31[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 15, 32)       0           conv1d_28[0][0]
#                                                                  conv1d_32[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 480)          0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 64)           30784       flatten_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 64)           0           dense_7[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 6)            390         dropout_4[0][0]
# ==================================================================================================
# Total params: 40,902
# Trainable params: 40,902
# Non-trainable params: 0
# __________________________________________________________________________________________________
# loss 0.0036984088364988565
# (10, 30, 28)
# video 143
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            (None, 30, 28)       0
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 30, 8)        3368        input_5[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 30, 8)        2248        input_5[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 30, 8)        648         conv1d_33[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 30, 8)        328         conv1d_37[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_9 (MaxPooling1D)  (None, 15, 8)        0           conv1d_34[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_10 (MaxPooling1D) (None, 15, 8)        0           conv1d_38[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 15, 16)       656         max_pooling1d_9[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 15, 16)       400         max_pooling1d_10[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 15, 16)       1296        conv1d_35[0][0]
# __________________________________________________________________________________________________
# conv1d_40 (Conv1D)              (None, 15, 16)       784         conv1d_39[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 15, 32)       0           conv1d_36[0][0]
#                                                                  conv1d_40[0][0]
# __________________________________________________________________________________________________
# flatten_5 (Flatten)             (None, 480)          0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 64)           30784       flatten_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 64)           0           dense_9[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 6)            390         dropout_5[0][0]
# ==================================================================================================
# Total params: 40,902
# Trainable params: 40,902
# Non-trainable params: 0
# __________________________________________________________________________________________________
# loss 0.05259595066308975
# (20, 30, 28)
# video 152
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            (None, 30, 28)       0
# __________________________________________________________________________________________________
# conv1d_41 (Conv1D)              (None, 30, 8)        3368        input_6[0][0]
# __________________________________________________________________________________________________
# conv1d_45 (Conv1D)              (None, 30, 8)        2248        input_6[0][0]
# __________________________________________________________________________________________________
# conv1d_42 (Conv1D)              (None, 30, 8)        648         conv1d_41[0][0]
# __________________________________________________________________________________________________
# conv1d_46 (Conv1D)              (None, 30, 8)        328         conv1d_45[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_11 (MaxPooling1D) (None, 15, 8)        0           conv1d_42[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_12 (MaxPooling1D) (None, 15, 8)        0           conv1d_46[0][0]
# __________________________________________________________________________________________________
# conv1d_43 (Conv1D)              (None, 15, 16)       656         max_pooling1d_11[0][0]
# __________________________________________________________________________________________________
# conv1d_47 (Conv1D)              (None, 15, 16)       400         max_pooling1d_12[0][0]
# __________________________________________________________________________________________________
# conv1d_44 (Conv1D)              (None, 15, 16)       1296        conv1d_43[0][0]
# __________________________________________________________________________________________________
# conv1d_48 (Conv1D)              (None, 15, 16)       784         conv1d_47[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 15, 32)       0           conv1d_44[0][0]
#                                                                  conv1d_48[0][0]
# __________________________________________________________________________________________________
# flatten_6 (Flatten)             (None, 480)          0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 64)           30784       flatten_6[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 64)           0           dense_11[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 6)            390         dropout_6[0][0]
# ==================================================================================================
# Total params: 40,902
# Trainable params: 40,902
# Non-trainable params: 0
# __________________________________________________________________________________________________
# loss 0.12878571450710297
# (10, 30, 28)
# video 164
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            (None, 30, 28)       0
# __________________________________________________________________________________________________
# conv1d_49 (Conv1D)              (None, 30, 8)        3368        input_7[0][0]
# __________________________________________________________________________________________________
# conv1d_53 (Conv1D)              (None, 30, 8)        2248        input_7[0][0]
# __________________________________________________________________________________________________
# conv1d_50 (Conv1D)              (None, 30, 8)        648         conv1d_49[0][0]
# __________________________________________________________________________________________________
# conv1d_54 (Conv1D)              (None, 30, 8)        328         conv1d_53[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_13 (MaxPooling1D) (None, 15, 8)        0           conv1d_50[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_14 (MaxPooling1D) (None, 15, 8)        0           conv1d_54[0][0]
# __________________________________________________________________________________________________
# conv1d_51 (Conv1D)              (None, 15, 16)       656         max_pooling1d_13[0][0]
# __________________________________________________________________________________________________
# conv1d_55 (Conv1D)              (None, 15, 16)       400         max_pooling1d_14[0][0]
# __________________________________________________________________________________________________
# conv1d_52 (Conv1D)              (None, 15, 16)       1296        conv1d_51[0][0]
# __________________________________________________________________________________________________
# conv1d_56 (Conv1D)              (None, 15, 16)       784         conv1d_55[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 15, 32)       0           conv1d_52[0][0]
#                                                                  conv1d_56[0][0]
# __________________________________________________________________________________________________
# flatten_7 (Flatten)             (None, 480)          0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 64)           30784       flatten_7[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 64)           0           dense_13[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 6)            390         dropout_7[0][0]
# ==================================================================================================
# Total params: 40,902
# Trainable params: 40,902
# Non-trainable params: 0
# __________________________________________________________________________________________________
# loss 0.1954583078622818
# (40, 30, 28)
# video 16
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            (None, 30, 28)       0
# __________________________________________________________________________________________________
# conv1d_57 (Conv1D)              (None, 30, 8)        3368        input_8[0][0]
# __________________________________________________________________________________________________
# conv1d_61 (Conv1D)              (None, 30, 8)        2248        input_8[0][0]
# __________________________________________________________________________________________________
# conv1d_58 (Conv1D)              (None, 30, 8)        648         conv1d_57[0][0]
# __________________________________________________________________________________________________
# conv1d_62 (Conv1D)              (None, 30, 8)        328         conv1d_61[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_15 (MaxPooling1D) (None, 15, 8)        0           conv1d_58[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_16 (MaxPooling1D) (None, 15, 8)        0           conv1d_62[0][0]
# __________________________________________________________________________________________________
# conv1d_59 (Conv1D)              (None, 15, 16)       656         max_pooling1d_15[0][0]
# __________________________________________________________________________________________________
# conv1d_63 (Conv1D)              (None, 15, 16)       400         max_pooling1d_16[0][0]
# __________________________________________________________________________________________________
# conv1d_60 (Conv1D)              (None, 15, 16)       1296        conv1d_59[0][0]
# __________________________________________________________________________________________________
# conv1d_64 (Conv1D)              (None, 15, 16)       784         conv1d_63[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 15, 32)       0           conv1d_60[0][0]
#                                                                  conv1d_64[0][0]
# __________________________________________________________________________________________________
# flatten_8 (Flatten)             (None, 480)          0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 64)           30784       flatten_8[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 64)           0           dense_15[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 6)            390         dropout_8[0][0]
# ==================================================================================================
# Total params: 40,902
# Trainable params: 40,902
# Non-trainable params: 0
# __________________________________________________________________________________________________
# loss 0.11222251132130623
# (100, 30, 28)
# video 171
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            (None, 30, 28)       0
# __________________________________________________________________________________________________
# conv1d_65 (Conv1D)              (None, 30, 8)        3368        input_9[0][0]
# __________________________________________________________________________________________________
# conv1d_69 (Conv1D)              (None, 30, 8)        2248        input_9[0][0]
# __________________________________________________________________________________________________
# conv1d_66 (Conv1D)              (None, 30, 8)        648         conv1d_65[0][0]
# __________________________________________________________________________________________________
# conv1d_70 (Conv1D)              (None, 30, 8)        328         conv1d_69[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_17 (MaxPooling1D) (None, 15, 8)        0           conv1d_66[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_18 (MaxPooling1D) (None, 15, 8)        0           conv1d_70[0][0]
# __________________________________________________________________________________________________
# conv1d_67 (Conv1D)              (None, 15, 16)       656         max_pooling1d_17[0][0]
# __________________________________________________________________________________________________
# conv1d_71 (Conv1D)              (None, 15, 16)       400         max_pooling1d_18[0][0]
# __________________________________________________________________________________________________
# conv1d_68 (Conv1D)              (None, 15, 16)       1296        conv1d_67[0][0]
# __________________________________________________________________________________________________
# conv1d_72 (Conv1D)              (None, 15, 16)       784         conv1d_71[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 15, 32)       0           conv1d_68[0][0]
#                                                                  conv1d_72[0][0]
# __________________________________________________________________________________________________
# flatten_9 (Flatten)             (None, 480)          0           concatenate_9[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 64)           30784       flatten_9[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 64)           0           dense_17[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 6)            390         dropout_9[0][0]
# ==================================================================================================
# Total params: 40,902
# Trainable params: 40,902
# Non-trainable params: 0
# __________________________________________________________________________________________________
# loss 0.0964103490114212
# (19, 30, 28)
# video 192
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_10 (InputLayer)           (None, 30, 28)       0
# __________________________________________________________________________________________________
# conv1d_73 (Conv1D)              (None, 30, 8)        3368        input_10[0][0]
# __________________________________________________________________________________________________
# conv1d_77 (Conv1D)              (None, 30, 8)        2248        input_10[0][0]
# __________________________________________________________________________________________________
# conv1d_74 (Conv1D)              (None, 30, 8)        648         conv1d_73[0][0]
# __________________________________________________________________________________________________
# conv1d_78 (Conv1D)              (None, 30, 8)        328         conv1d_77[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_19 (MaxPooling1D) (None, 15, 8)        0           conv1d_74[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_20 (MaxPooling1D) (None, 15, 8)        0           conv1d_78[0][0]
# __________________________________________________________________________________________________
# conv1d_75 (Conv1D)              (None, 15, 16)       656         max_pooling1d_19[0][0]
# __________________________________________________________________________________________________
# conv1d_79 (Conv1D)              (None, 15, 16)       400         max_pooling1d_20[0][0]
# __________________________________________________________________________________________________
# conv1d_76 (Conv1D)              (None, 15, 16)       1296        conv1d_75[0][0]
# __________________________________________________________________________________________________
# conv1d_80 (Conv1D)              (None, 15, 16)       784         conv1d_79[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 15, 32)       0           conv1d_76[0][0]
#                                                                  conv1d_80[0][0]
# __________________________________________________________________________________________________
# flatten_10 (Flatten)            (None, 480)          0           concatenate_10[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 64)           30784       flatten_10[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 64)           0           dense_19[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 6)            390         dropout_10[0][0]
# ==================================================================================================
# Total params: 40,902
# Trainable params: 40,902
# Non-trainable params: 0
# __________________________________________________________________________________________________
# loss 0.17102012038230896
# (5, 30, 28)
# video 176
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_11 (InputLayer)           (None, 30, 28)       0
# __________________________________________________________________________________________________
# conv1d_81 (Conv1D)              (None, 30, 8)        3368        input_11[0][0]
# __________________________________________________________________________________________________
# conv1d_85 (Conv1D)              (None, 30, 8)        2248        input_11[0][0]
# __________________________________________________________________________________________________
# conv1d_82 (Conv1D)              (None, 30, 8)        648         conv1d_81[0][0]
# __________________________________________________________________________________________________
# conv1d_86 (Conv1D)              (None, 30, 8)        328         conv1d_85[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_21 (MaxPooling1D) (None, 15, 8)        0           conv1d_82[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_22 (MaxPooling1D) (None, 15, 8)        0           conv1d_86[0][0]
# __________________________________________________________________________________________________
# conv1d_83 (Conv1D)              (None, 15, 16)       656         max_pooling1d_21[0][0]
# __________________________________________________________________________________________________
# conv1d_87 (Conv1D)              (None, 15, 16)       400         max_pooling1d_22[0][0]
# __________________________________________________________________________________________________
# conv1d_84 (Conv1D)              (None, 15, 16)       1296        conv1d_83[0][0]
# __________________________________________________________________________________________________
# conv1d_88 (Conv1D)              (None, 15, 16)       784         conv1d_87[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 15, 32)       0           conv1d_84[0][0]
#                                                                  conv1d_88[0][0]
# __________________________________________________________________________________________________
# flatten_11 (Flatten)            (None, 480)          0           concatenate_11[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 64)           30784       flatten_11[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 64)           0           dense_21[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 6)            390         dropout_11[0][0]
# ==================================================================================================
# Total params: 40,902
# Trainable params: 40,902
# Non-trainable params: 0
# __________________________________________________________________________________________________
# loss 0.11256689578294754
# (100, 30, 28)
# video 207
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_12 (InputLayer)           (None, 30, 28)       0
# __________________________________________________________________________________________________
# conv1d_89 (Conv1D)              (None, 30, 8)        3368        input_12[0][0]
# __________________________________________________________________________________________________
# conv1d_93 (Conv1D)              (None, 30, 8)        2248        input_12[0][0]
# __________________________________________________________________________________________________
# conv1d_90 (Conv1D)              (None, 30, 8)        648         conv1d_89[0][0]
# __________________________________________________________________________________________________
# conv1d_94 (Conv1D)              (None, 30, 8)        328         conv1d_93[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_23 (MaxPooling1D) (None, 15, 8)        0           conv1d_90[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_24 (MaxPooling1D) (None, 15, 8)        0           conv1d_94[0][0]
# __________________________________________________________________________________________________
# conv1d_91 (Conv1D)              (None, 15, 16)       656         max_pooling1d_23[0][0]
# __________________________________________________________________________________________________
# conv1d_95 (Conv1D)              (None, 15, 16)       400         max_pooling1d_24[0][0]
# __________________________________________________________________________________________________
# conv1d_92 (Conv1D)              (None, 15, 16)       1296        conv1d_91[0][0]
# __________________________________________________________________________________________________
# conv1d_96 (Conv1D)              (None, 15, 16)       784         conv1d_95[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 15, 32)       0           conv1d_92[0][0]
#                                                                  conv1d_96[0][0]
# __________________________________________________________________________________________________
# flatten_12 (Flatten)            (None, 480)          0           concatenate_12[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 64)           30784       flatten_12[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 64)           0           dense_23[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 6)            390         dropout_12[0][0]
# ==================================================================================================
# Total params: 40,902
# Trainable params: 40,902
# Non-trainable params: 0
# __________________________________________________________________________________________________
# loss 0.03813261538743973
# (10, 30, 28)
# video 194
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_13 (InputLayer)           (None, 30, 28)       0
# __________________________________________________________________________________________________
# conv1d_97 (Conv1D)              (None, 30, 8)        3368        input_13[0][0]
# __________________________________________________________________________________________________
# conv1d_101 (Conv1D)             (None, 30, 8)        2248        input_13[0][0]
# __________________________________________________________________________________________________
# conv1d_98 (Conv1D)              (None, 30, 8)        648         conv1d_97[0][0]
# __________________________________________________________________________________________________
# conv1d_102 (Conv1D)             (None, 30, 8)        328         conv1d_101[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_25 (MaxPooling1D) (None, 15, 8)        0           conv1d_98[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_26 (MaxPooling1D) (None, 15, 8)        0           conv1d_102[0][0]
# __________________________________________________________________________________________________
# conv1d_99 (Conv1D)              (None, 15, 16)       656         max_pooling1d_25[0][0]
# __________________________________________________________________________________________________
# conv1d_103 (Conv1D)             (None, 15, 16)       400         max_pooling1d_26[0][0]
# __________________________________________________________________________________________________
# conv1d_100 (Conv1D)             (None, 15, 16)       1296        conv1d_99[0][0]
# __________________________________________________________________________________________________
# conv1d_104 (Conv1D)             (None, 15, 16)       784         conv1d_103[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 15, 32)       0           conv1d_100[0][0]
#                                                                  conv1d_104[0][0]
# __________________________________________________________________________________________________
# flatten_13 (Flatten)            (None, 480)          0           concatenate_13[0][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 64)           30784       flatten_13[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 64)           0           dense_25[0][0]
# __________________________________________________________________________________________________
# dense_26 (Dense)                (None, 6)            390         dropout_13[0][0]
# ==================================================================================================
# Total params: 40,902
# Trainable params: 40,902
# Non-trainable params: 0
# __________________________________________________________________________________________________
# loss 0.06379567086696625
# (100, 30, 28)
# video 236
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_14 (InputLayer)           (None, 30, 28)       0
# __________________________________________________________________________________________________
# conv1d_105 (Conv1D)             (None, 30, 8)        3368        input_14[0][0]
# __________________________________________________________________________________________________
# conv1d_109 (Conv1D)             (None, 30, 8)        2248        input_14[0][0]
# __________________________________________________________________________________________________
# conv1d_106 (Conv1D)             (None, 30, 8)        648         conv1d_105[0][0]
# __________________________________________________________________________________________________
# conv1d_110 (Conv1D)             (None, 30, 8)        328         conv1d_109[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_27 (MaxPooling1D) (None, 15, 8)        0           conv1d_106[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_28 (MaxPooling1D) (None, 15, 8)        0           conv1d_110[0][0]
# __________________________________________________________________________________________________
# conv1d_107 (Conv1D)             (None, 15, 16)       656         max_pooling1d_27[0][0]
# __________________________________________________________________________________________________
# conv1d_111 (Conv1D)             (None, 15, 16)       400         max_pooling1d_28[0][0]
# __________________________________________________________________________________________________
# conv1d_108 (Conv1D)             (None, 15, 16)       1296        conv1d_107[0][0]
# __________________________________________________________________________________________________
# conv1d_112 (Conv1D)             (None, 15, 16)       784         conv1d_111[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 15, 32)       0           conv1d_108[0][0]
# ...
# dense_39 (Dense)                (None, 64)           30784       flatten_20[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 64)           0           dense_39[0][0]
# __________________________________________________________________________________________________
# dense_40 (Dense)                (None, 6)            390         dropout_20[0][0]
# ==================================================================================================
# Total params: 40,902
# Trainable params: 40,902
# Non-trainable params: 0
# __________________________________________________________________________________________________
# loss 0.003920902032405138
# (20, 30, 28)
# video 59
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_21 (InputLayer)           (None, 30, 28)       0
# __________________________________________________________________________________________________
# conv1d_161 (Conv1D)             (None, 30, 8)        3368        input_21[0][0]
# __________________________________________________________________________________________________
# conv1d_165 (Conv1D)             (None, 30, 8)        2248        input_21[0][0]
# __________________________________________________________________________________________________
# conv1d_162 (Conv1D)             (None, 30, 8)        648         conv1d_161[0][0]
# __________________________________________________________________________________________________
# conv1d_166 (Conv1D)             (None, 30, 8)        328         conv1d_165[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_41 (MaxPooling1D) (None, 15, 8)        0           conv1d_162[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_42 (MaxPooling1D) (None, 15, 8)        0           conv1d_166[0][0]
# __________________________________________________________________________________________________
# conv1d_163 (Conv1D)             (None, 15, 16)       656         max_pooling1d_41[0][0]
# __________________________________________________________________________________________________
# conv1d_167 (Conv1D)             (None, 15, 16)       400         max_pooling1d_42[0][0]
# __________________________________________________________________________________________________
# conv1d_164 (Conv1D)             (None, 15, 16)       1296        conv1d_163[0][0]
# __________________________________________________________________________________________________
# conv1d_168 (Conv1D)             (None, 15, 16)       784         conv1d_167[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 15, 32)       0           conv1d_164[0][0]
#                                                                  conv1d_168[0][0]
# __________________________________________________________________________________________________
# flatten_21 (Flatten)            (None, 480)          0           concatenate_21[0][0]
# __________________________________________________________________________________________________
# dense_41 (Dense)                (None, 64)           30784       flatten_21[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 64)           0           dense_41[0][0]
# __________________________________________________________________________________________________
# dense_42 (Dense)                (None, 6)            390         dropout_21[0][0]
# ==================================================================================================
# Total params: 40,902
# Trainable params: 40,902
# Non-trainable params: 0
# __________________________________________________________________________________________________
# loss 0.10095315426588058
# (40, 30, 28)
# video 74
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_22 (InputLayer)           (None, 30, 28)       0
# __________________________________________________________________________________________________
# conv1d_169 (Conv1D)             (None, 30, 8)        3368        input_22[0][0]
# __________________________________________________________________________________________________
# conv1d_173 (Conv1D)             (None, 30, 8)        2248        input_22[0][0]
# __________________________________________________________________________________________________
# conv1d_170 (Conv1D)             (None, 30, 8)        648         conv1d_169[0][0]
# __________________________________________________________________________________________________
# conv1d_174 (Conv1D)             (None, 30, 8)        328         conv1d_173[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_43 (MaxPooling1D) (None, 15, 8)        0           conv1d_170[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_44 (MaxPooling1D) (None, 15, 8)        0           conv1d_174[0][0]
# __________________________________________________________________________________________________
# conv1d_171 (Conv1D)             (None, 15, 16)       656         max_pooling1d_43[0][0]
# __________________________________________________________________________________________________
# conv1d_175 (Conv1D)             (None, 15, 16)       400         max_pooling1d_44[0][0]
# __________________________________________________________________________________________________
# conv1d_172 (Conv1D)             (None, 15, 16)       1296        conv1d_171[0][0]
# __________________________________________________________________________________________________
# conv1d_176 (Conv1D)             (None, 15, 16)       784         conv1d_175[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 15, 32)       0           conv1d_172[0][0]
#                                                                  conv1d_176[0][0]
# __________________________________________________________________________________________________
# flatten_22 (Flatten)            (None, 480)          0           concatenate_22[0][0]
# __________________________________________________________________________________________________
# dense_43 (Dense)                (None, 64)           30784       flatten_22[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 64)           0           dense_43[0][0]
# __________________________________________________________________________________________________
# dense_44 (Dense)                (None, 6)            390         dropout_22[0][0]
# ==================================================================================================
# Total params: 40,902
# Trainable params: 40,902
# Non-trainable params: 0
# __________________________________________________________________________________________________
# loss 0.058535508811473846
# (20, 30, 28)
# video 78
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_23 (InputLayer)           (None, 30, 28)       0
# __________________________________________________________________________________________________
# conv1d_177 (Conv1D)             (None, 30, 8)        3368        input_23[0][0]
# __________________________________________________________________________________________________
# conv1d_181 (Conv1D)             (None, 30, 8)        2248        input_23[0][0]
# __________________________________________________________________________________________________
# conv1d_178 (Conv1D)             (None, 30, 8)        648         conv1d_177[0][0]
# __________________________________________________________________________________________________
# conv1d_182 (Conv1D)             (None, 30, 8)        328         conv1d_181[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_45 (MaxPooling1D) (None, 15, 8)        0           conv1d_178[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_46 (MaxPooling1D) (None, 15, 8)        0           conv1d_182[0][0]
# __________________________________________________________________________________________________
# conv1d_179 (Conv1D)             (None, 15, 16)       656         max_pooling1d_45[0][0]
# __________________________________________________________________________________________________
# conv1d_183 (Conv1D)             (None, 15, 16)       400         max_pooling1d_46[0][0]
# __________________________________________________________________________________________________
# conv1d_180 (Conv1D)             (None, 15, 16)       1296        conv1d_179[0][0]
# __________________________________________________________________________________________________
# conv1d_184 (Conv1D)             (None, 15, 16)       784         conv1d_183[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 15, 32)       0           conv1d_180[0][0]
#                                                                  conv1d_184[0][0]
# __________________________________________________________________________________________________
# flatten_23 (Flatten)            (None, 480)          0           concatenate_23[0][0]
# __________________________________________________________________________________________________
# dense_45 (Dense)                (None, 64)           30784       flatten_23[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 64)           0           dense_45[0][0]
# __________________________________________________________________________________________________
# dense_46 (Dense)                (None, 6)            390         dropout_23[0][0]
# ==================================================================================================
# Total params: 40,902
# Trainable params: 40,902
# Non-trainable params: 0
# __________________________________________________________________________________________________
# loss 0.008403969928622246
# (10, 30, 28)
# video 91
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_24 (InputLayer)           (None, 30, 28)       0
# __________________________________________________________________________________________________
# conv1d_185 (Conv1D)             (None, 30, 8)        3368        input_24[0][0]
# __________________________________________________________________________________________________
# conv1d_189 (Conv1D)             (None, 30, 8)        2248        input_24[0][0]
# __________________________________________________________________________________________________
# conv1d_186 (Conv1D)             (None, 30, 8)        648         conv1d_185[0][0]
# __________________________________________________________________________________________________
# conv1d_190 (Conv1D)             (None, 30, 8)        328         conv1d_189[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_47 (MaxPooling1D) (None, 15, 8)        0           conv1d_186[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_48 (MaxPooling1D) (None, 15, 8)        0           conv1d_190[0][0]
# __________________________________________________________________________________________________
# conv1d_187 (Conv1D)             (None, 15, 16)       656         max_pooling1d_47[0][0]
# __________________________________________________________________________________________________
# conv1d_191 (Conv1D)             (None, 15, 16)       400         max_pooling1d_48[0][0]
# __________________________________________________________________________________________________
# conv1d_188 (Conv1D)             (None, 15, 16)       1296        conv1d_187[0][0]
# __________________________________________________________________________________________________
# conv1d_192 (Conv1D)             (None, 15, 16)       784         conv1d_191[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 15, 32)       0           conv1d_188[0][0]
#                                                                  conv1d_192[0][0]
# __________________________________________________________________________________________________
# flatten_24 (Flatten)            (None, 480)          0           concatenate_24[0][0]
# __________________________________________________________________________________________________
# dense_47 (Dense)                (None, 64)           30784       flatten_24[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 64)           0           dense_47[0][0]
# __________________________________________________________________________________________________
# dense_48 (Dense)                (None, 6)            390         dropout_24[0][0]
# ==================================================================================================
# Total params: 40,902
# Trainable params: 40,902
# Non-trainable params: 0
# __________________________________________________________________________________________________
# loss 0.19650155305862427
# (10, 30, 28)
# total_loss=  2.311509178718552

# %%
# ####################################### set video clips parameters
# ############################################### make new 28-d feature
# video_clips_length=[30,60]
# time_lag=[1,2]
# move_threshold=[100,200]
# # stride=int(video_clips_length)

# ####################################### set video clips parameters
# ############################################### make new 28-d feature

# for vl in video_clips_length:
#     for tl in time_lag:
#         for mt in move_threshold:
#             S=[int(vl),int(vl/2)]
#             for stride in S:
#                 print('video_clips_length',vl,' time_lag',tl,'move_threshold',mt,'stride',stride)

#                 all_data=[]
                
#                 for each_video,label in zip(X,Y):

#                     re=get_diff_and_hstack_to_orginal_data(each_video,tl,mt)
#                     video_clip=make_video_clips(re,vl,stride)
#     #                 print(video_clip.shape)
#                     all_data.append((video_clip))
        
#                 total_loss=0
#                 show_result=True
#                 for i in Y:
#                     print('video',i)
#                     loss=test_hold_out(i,show_result)
#                     total_loss=total_loss+loss
#                 print('total_loss= ',total_loss)

# %%
# video_clips_length 30  time_lag 1 move_threshold 100 stride 30
# total_loss=  1.412462801206857
# video_clips_length 30  time_lag 1 move_threshold 100 stride 15
# total_loss=  1.4150967202149332
# video_clips_length 30  time_lag 1 move_threshold 200 stride 30
# total_loss=  1.397022263146937
# video_clips_length 30  time_lag 1 move_threshold 200 stride 15
# total_loss=  1.4331296226009727
# video_clips_length 30  time_lag 2 move_threshold 100 stride 30
# total_loss=  1.3969617546536028
# video_clips_length 30  time_lag 2 move_threshold 100 stride 15
# total_loss=  1.4400804012548178
# video_clips_length 30  time_lag 2 move_threshold 200 stride 30
# total_loss=  1.3962573492899537
# video_clips_length 30  time_lag 2 move_threshold 200 stride 15
# total_loss=  1.425527356332168
