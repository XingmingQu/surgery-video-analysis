# %%
import pandas as pd
from modules import labelHelper as lh

# %%
ll=lh.Label("../2019_fall_labels.csv")

review_times=[ll.get_review_times_by_video_number(i) for i in ll.get_video_number()]
videoN=[str(i) for i in ll.get_video_number()]
review_times

import matplotlib.pyplot as plt

objects = videoN
y_pos = np.arange(len(objects))
performance =review_times

figure=plt.figure(figsize=(35,19))

plt.bar(y_pos, performance, align='edge', width=0.4)
plt.xticks(y_pos, objects)
plt.ylabel('Review times')
plt.xlabel('Video number')
#plt.title('Programming language usage')

plt.show()
figure.savefig('foo.png', bbox_inches='tight')

# %%
data=pd.read_csv("../reviewer_list.csv")

# %%
data.drop_duplicates(keep=False,inplace=True)

# %%
data.groupby(["VideoNum","reviewer"]).head()
# Out:
#      VideoNum   reviewer  DP  BD  E  FS  A  RC  sumScore
# 2          11      Gahan   2   2  3   1  3   3        14
# 3          11    Johnson   1   1  1   1  1   1         6
# 4          11      Gahan   3   3  2   2  2   2        14
# 7          16      Woldu   1   1  1   1  1   1         6
# 8          16      Gahan   2   1  1   1  1   2         8
# 9          16    Johnson   1   1  1   1  1   1         6
# 10         16    Garbens   2   2  1   2  3   2        12
# 11         49      Woldu   3   4  2   2  3   3        17
# 12         49      Gahan   3   3  3   2  3   3        17
# 13         49    Johnson   3   2  1   3  2   2        13
# 14         49  Steinberg   4   3  3   4  3   4        21
# 15         49    Johnson   1   2  2   1  1   1         8
# 16         49    Garbens   3   3  2   2  4   2        16
# 17         59      Woldu   2   2  2   2  2   2        12
# 18         59      Gahan   3   2  2   2  2   2        13
# ...
